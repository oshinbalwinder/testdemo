# %%
import pandas as pd
p = pd.read_csv('president_heights.csv', skiprows = 5, header=None)
p
# Out:
#      0                       1    2
# 0    5            James Monroe  183
# 1    6       John Quincy Adams  171
# 2    7          Andrew Jackson  185
# 3    8        Martin Van Buren  168
# 4    9  William Henry Harrison  173
# 5   10              John Tyler  183
# 6   11           James K. Polk  173
# 7   12          Zachary Taylor  173
# 8   13        Millard Fillmore  175
# 9   14         Franklin Pierce  178
# 10  15          James Buchanan  183
# 11  16         Abraham Lincoln  193
# 12  17          Andrew Johnson  178
# 13  18        Ulysses S. Grant  173
# 14  19     Rutherford B. Hayes  174
# 15  20       James A. Garfield  183
# 16  21       Chester A. Arthur  183
# 17  23       Benjamin Harrison  168
# 18  25        William McKinley  170
# 19  26      Theodore Roosevelt  178
# 20  27     William Howard Taft  182
# 21  28          Woodrow Wilson  180
# 22  29       Warren G. Harding  183
# 23  30         Calvin Coolidge  178
# 24  31          Herbert Hoover  182
# 25  32   Franklin D. Roosevelt  188
# 26  33         Harry S. Truman  175
# 27  34    Dwight D. Eisenhower  179
# 28  35         John F. Kennedy  183
# 29  36       Lyndon B. Johnson  193
# 30  37           Richard Nixon  182
# 31  38             Gerald Ford  183
# 32  39            Jimmy Carter  177
# 33  40           Ronald Reagan  185
# 34  41       George H. W. Bush  188
# 35  42            Bill Clinton  188
# 36  43          George W. Bush  182
# 37  44            Barack Obama  185

# %%
df_list = pd.read_html( "https://ourworldindata.org/ofdacred-international-disaster-data" )
len(df_list)

data = requests.get('https://ourworldindata.org/ofdacred-international-disaster-data')

# %%
df_table1 = df_list[0]

# %%
df_table1
# Out:
#    Yearly average global annual deaths from natural disasters, by decade  \
# 0                                               1900s
# 1                                               1910s
# 2                                               1920s
# 3                                               1930s
# 4                                               1940s
# 5                                               1950s
# 6                                               1960s
# 7                                               1970s
# 8                                               1980s
# 9                                               1990s
# 10                                              2000s
# 11                                              2010s
#
#     Drought  Earthquake  Extreme temperature   Flood  Impact  Landslide  \
# 0    130000       17302                    0      63       0          5
# 1      8500        6280                    0   10138       0          0
# 2    472400       54935                    0     428       0         43
# 3         0       23770                  169  436147       0        103
# 4    345000       16187                    0   10103       0       1753
# 5         0        2093                  150  205830       0        215
# 6    150865        5236                  113    3239       0        504
# 7     11908       44022                  155    5078       0        738
# 8     55727        6015                  534    5155       0        623
# 9       311       10359                  932    9549       0        833
# 10      115       45364                 9106    5401       0        772
# 11     3339       43302                11644    5811       0       1069
#
#     Mass movement (dry)  Storm  Volcanic activity  Wildfire
# 0                    13   1801               4494         0
# 1                    12   5995                648       107
# 2                     0  11999                514        10
# 3                     4   9384                318         7
# 4                     0  12712                213        25
# 5                     0   3126                510         1
# 6                   218  13393                324         7
# 7                     7  35734                 53         1
# 8                   127   4667               2400        40
# 9                    87  21115                 97        86
# 10                   28  17213                 24        63
# 11                   13   3177                 71        52

# %%
import numpy as np
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'], 'key2' : ['one', 'two', 'one', 'two', 'one'], 'data1' : np.random.randn(5), 'data2' : np.random.randn(5)})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.270842  0.333743
# 1    a  two  1.408168  0.333866
# 2    b  one  0.691409 -0.145442
# 3    b  two -0.454636  1.590690
# 4    a  one  0.497924  0.525160

# %%
df['data1'].groupby(df['key1'])
for group in df['data1'].groupby(df['key1']):
    print(group)
# Out:
# ('a', 0   -0.270842
# 1    1.408168
# 4    0.497924
# Name: data1, dtype: float64)
# ('b', 2    0.691409
# 3   -0.454636
# Name: data1, dtype: float64)

# %%
for name, group in df['data1'].groupby(df['key1']):
    print(name)
    print(group)
# Out:
# a
# 0   -0.270842
# 1    1.408168
# 4    0.497924
# Name: data1, dtype: float64
# b
# 2    0.691409
# 3   -0.454636
# Name: data1, dtype: float64

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped.mean()
# Out:
# key1
# a    0.545083
# b    0.118387
# Name: data1, dtype: float64

# %%
df['data2'].groupby(df['key1']).sum()
# Out:
# key1
# a    1.192770
# b    1.445249
# Name: data2, dtype: float64

# %%
 means = df['data1'].groupby([df['key1'], df['key2']]).mean()
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.270842  0.333743
# 1    a  two  1.408168  0.333866
# 2    b  one  0.691409 -0.145442
# 3    b  two -0.454636  1.590690
# 4    a  one  0.497924  0.525160

# %%
means
# Out:
# key1  key2
# a     one    -0.595519
#       two    -0.048241
# b     one     1.244966
#       two    -0.995720
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a    -0.595519 -0.048241
# b     1.244966 -0.995720

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])

# %%
years = np.array([2005, 2005, 2006, 2005, 2006])
population = np.array([1908745, 789465166, 574875459,4544646,4545454])

# %%
df1 = pd.DataFrame({'states':states, 'years': years, 'population': population})
df1
# Out:
#        states  years  population
# 0        Ohio   2005     1908745
# 1  California   2005   789465166
# 2  California   2006   574875459
# 3        Ohio   2005     4544646
# 4        Ohio   2006     4545454

# %%
df1['population'].groupby([df1['years'], df1['states']]).mean()
# Out:
# years  states
# 2005   California    789465166.0
#        Ohio            3226695.5
# 2006   California    574875459.0
#        Ohio            4545454.0
# Name: population, dtype: float64

# %%
df1.groupby([df1['years'], df1['states']]).size()
# Out:
# years  states
# 2005   California    1
#        Ohio          2
# 2006   California    1
#        Ohio          1
# dtype: int64

# %%
for name, group in df1.groupby(df1['years']):
    print("name is ", name)
    print("group is", group)
# Out:
# name is  2005
# group is        states  years  population
# 0        Ohio   2005     1908745
# 1  California   2005   789465166
# 3        Ohio   2005     4544646
# name is  2006
# group is        states  years  population
# 2  California   2006   574875459
# 4        Ohio   2006     4545454

# %%
for name, group in df1.groupby(df1['years'])['population']:
    print(name)
    print(group)
# Out:
# 2005
# 0      1908745
# 1    789465166
# 3      4544646
# Name: population, dtype: int32
# 2006
# 2    574875459
# 4      4545454
# Name: population, dtype: int32

# %%
g = df1.groupby(df1['years'])

# %%
for group in g:
    print(group)
# Out:
# (2005,        states  years  population
# 0        Ohio   2005     1908745
# 1  California   2005   789465166
# 3        Ohio   2005     4544646)
# (2006,        states  years  population
# 2  California   2006   574875459
# 4        Ohio   2006     4545454)

# %%
marks = pd.read_excel('student_details.xlsx')

# %%
data = pd.DataFrame(marks)
data
# Out:
#     Student Id     Name Course                Subject  Marks
# 0       383080      Ray     AI                 Python     85
# 1       383080      Ray     AI      Data Manipulation     80
# 2       383080      Ray     AI          Visualization     90
# 3       412290   Amreen     ML             Regression     85
# 4       412290   Amreen     ML    Supervised learning     89
# 5       412290   Amreen     ML  Unsupervised Learning     84
# 6       412290   Amreen     ML                  Maths     86
# 7       412290   Amreen     ML                     PE     85
# 8       218895  Loralai     DS                 Hadoop     82
# 9       218895  Loralai     DS                  Spark     90
# 10      218895  Loralai     DS                 Python     86
# 11      218895  Loralai     DS                     DM     95

# %%
data.groupby(data['Course'])['Marks'].sum()
# Out:
# Course
# AI    255
# DS    353
# ML    429
# Name: Marks, dtype: int64

# %%
import pandas as pd
df = pd.read_excel("student_details.xlsx")

df.groupby('Course')["Marks"].sum()

Marks_total = df.groupby('Course')["Marks"].sum().rename("Marks_Total").reset_index()

df_1 = df.merge(Marks_total)

df_1["Percent_of_marks"] = df_1["Marks"] / df_1["Marks_Total"]
df_1
# Out:
#     Student Id     Name Course                Subject  Marks  Marks_Total  \
# 0       383080      Ray     AI                 Python     85          255
# 1       383080      Ray     AI      Data Manipulation     80          255
# 2       383080      Ray     AI          Visualization     90          255
# 3       412290   Amreen     ML             Regression     85          429
# 4       412290   Amreen     ML    Supervised learning     89          429
# 5       412290   Amreen     ML  Unsupervised Learning     84          429
# 6       412290   Amreen     ML                  Maths     86          429
# 7       412290   Amreen     ML                     PE     85          429
# 8       218895  Loralai     DS                 Hadoop     82          353
# 9       218895  Loralai     DS                  Spark     90          353
# 10      218895  Loralai     DS                 Python     86          353
# 11      218895  Loralai     DS                     DM     95          353
#
#     Percent_of_marks
# 0           0.333333
# 1           0.313725
# 2           0.352941
# 3           0.198135
# 4           0.207459
# 5           0.195804
# 6           0.200466
# 7           0.198135
# 8           0.232295
# 9           0.254958
# 10          0.243626
# 11          0.269122

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
flowers = pd.read_csv(url,header=None,names=['a','b','c','d','e'])
flowers
# Out:
#        a    b    c    d               e
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
flowers.rename(columns={'a':'sepal_l','b':'sepal_w', 'c':'petal_l','d':'petal_w','e':'species'}, inplace = True)
flowers
# Out:
#      sepal_l  sepal_w  petal_l  petal_w         species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(flowers.describe())
# Out:
#           sepal_l     sepal_w     petal_l     petal_w
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
a = [1,2,3]
b=  [3,4,5]

# %%
n1 = np.array([1,2,3])
n2 = np.array([3,4,5])

# %%
d = np.append(n1,n2)
d1 = np.unique(d)
print(d1)
# Out:
# [1 2 3 4 5]

# %%
from sklearn.preprocessing import LabelEncoder
D = ['A','B','B','C','D','E','B','A']
le = LabelEncoder()
print(le.fit_transform(D))
# Out:
# [0 1 1 2 3 4 1 0]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
# creating initial dataframe
bridge_types = ('Arch','Beam','Truss','Cantilever','Tied Arch','Suspension','Cable')
bridge_df = pd.DataFrame(bridge_types, columns=['Bridge_Types'])
print(bridge_df)
# creating instance of labelencoder
l = LabelEncoder()
# Assigning numerical values and storing in another column
bridge_df['Bridge_Types_Cat'] = l.fit_transform(bridge_df['Bridge_Types'])
bridge_df
# Out:
#   Bridge_Types
# 0         Arch
# 1         Beam
# 2        Truss
# 3   Cantilever
# 4    Tied Arch
# 5   Suspension
# 6        Cable
#   Bridge_Types  Bridge_Types_Cat
# 0         Arch                 0
# 1         Beam                 1
# 2        Truss                 6
# 3   Cantilever                 3
# 4    Tied Arch                 5
# 5   Suspension                 4
# 6        Cable                 2

# %%
st = pd.DataFrame({'student':['A','A','B'], 'program':['ML','ML','AI'],'course':['DS','Python','DS'],'Marks':[50,48,56]})

# %%
st
# Out:
#   student program  course  Marks
# 0       A      ML      DS     50
# 1       A      ML  Python     48
# 2       B      AI      DS     56

# %%
st.groupby(st['program'])['course'].size()
# Out:
# program
# AI    1
# ML    2
# Name: course, dtype: int64

# %%
for name, group in st.groupby(st['program'])['course']:
    print(name)
    print(group)
# Out:
# AI
# 2    DS
# Name: course, dtype: object
# ML
# 0        DS
# 1    Python
# Name: course, dtype: object

# %%
data = pd.DataFrame({'elec' : [2000,2500,3000], 'month':[1,2,3]})

# %%
d = pd.concat([data]*30, ignore_index=True)
d
# Out:
#     elec  month
# 0   2000      1
# 1   2500      2
# 2   3000      3
# 3   2000      1
# 4   2500      2
# ..   ...    ...
# 85  2500      2
# 86  3000      3
# 87  2000      1
# 88  2500      2
# 89  3000      3
#
# [90 rows x 2 columns]

# %%
n = pd.Series(range(1,31))

pd.DataFrame({'month':[1,2,3], 'days':range(1,10)})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-534-8e63a5a7382e> in <module>
#       1 n = pd.Series(range(1,31))
#       2
# ----> 3 pd.DataFrame({'month':[1,2,3], 'days':range(1,10)})
#       4
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length
